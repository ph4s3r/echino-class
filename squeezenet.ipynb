# %% [markdown]
# **Importing modules and loading data**

# %%
# %run ./echino_loader.ipynb
tile_size = 500 # pixels
# Out:
# Imports complete
# Loaded 92 images from /pml/wsi_data
#
# Paths are all set, dataset splitting done

# %%
caseRandomizer()
# Out:
# Loaded 92 images from /pml/wsi_data
# (['echino_76_3',
#   'echino61',
#   'echino_72_002',
#   'echino51',
#   'echino_77_1',
#   'norm25',
#   'Normalliver16',
#   'echino28',
#   'norm12',
#   'normal_70',
#   'echino_79_1',
#   'echino24',
#   'normal3',
#   'echino38',
#   'echino26',
#   'echino17',
#   'echino36',
#   'echino_69_03',
#   'echino50',
#   'echino_69_3',
#   'norm_79_1',
#   'echino39',
#   'echino14',
#   'norm26',
#   'echino41',
#   'normal2',
#   'Norm21',
#   'Normalliver19',
#   'echino31',
#   'echino32',
#   'echino13',
#   'echino_71_2',
#   'Norm22',
#   'echino19',
#   'echino23',
#   'normal5',
#   'normal1',
#   'normal4',
#   'Norm20',
#   'echino_72_001',
#   'echino_78_2',
#   'normal6',
#   'echino_74_001',
#   'normal8',
#   'echino8',
#   'echino_69_02',
#   'echino3',
#   'norm13',
#   'echino60',
#   'Normalliver18',
#   'echino25',
#   'echino_69_1',
#   'echino_75_002',
#   'echino_71_002',
#   'normal_69_1'],
#  ['normal7',
#   'echino40',
#   'norm_80_0001',
#   'echino52',
#   'echino_71_003',
#   'norm_75_001',
#   'norm_72_01',
#   'norm_69_01',
#   'echino_69_4',
#   'echino_76_1',
#   'echino_72_2',
#   'echino30',
#   'echino42',
#   'Normalliver20',
#   'echino21',
#   'normal14',
#   'echino_71_1',
#   'echino62'],
#  ['Norm23',
#   'Normalliver15',
#   'echino15',
#   'echino35',
#   'echino_75_001',
#   'echino_71_001',
#   'echino_72_1',
#   'normal9',
#   'echino16',
#   'echino_76_2',
#   'echino_80_1',
#   'norm24',
#   'norm_71_1',
#   'echino29',
#   'echino_69_2',
#   'norm_72_1',
#   'echino27',
#   'echino_73_01',
#   'normal10'])

# %% [markdown]
# **Tissue detection**

# %%
# it checks for existing pml files
tissueDetection(tile_size)
# Out:
# pml file exists for echino_76_3 as /pml/slides/echino_76_3.pml
# pml file exists for echino61 as /pml/slides/echino61.pml
# pml file exists for echino_72_002 as /pml/slides/echino_72_002.pml
# pml file exists for echino51 as /pml/slides/echino51.pml
# pml file exists for echino_77_1 as /pml/slides/echino_77_1.pml
# pml file exists for norm25 as /pml/slides/norm25.pml
# pml file exists for Normalliver16 as /pml/slides/Normalliver16.pml
# pml file exists for echino28 as /pml/slides/echino28.pml
# pml file exists for norm12 as /pml/slides/norm12.pml
# pml file exists for normal_70 as /pml/slides/normal_70.pml
# pml file exists for echino_79_1 as /pml/slides/echino_79_1.pml
# pml file exists for echino24 as /pml/slides/echino24.pml
# pml file exists for normal3 as /pml/slides/normal3.pml
# pml file exists for echino38 as /pml/slides/echino38.pml
# pml file exists for echino26 as /pml/slides/echino26.pml
# pml file exists for echino17 as /pml/slides/echino17.pml
# pml file exists for echino36 as /pml/slides/echino36.pml
# pml file exists for echino_69_03 as /pml/slides/echino_69_03.pml
# pml file exists for echino50 as /pml/slides/echino50.pml
# pml file exists for echino_69_3 as /pml/slides/echino_69_3.pml
# pml file exists for norm_79_1 as /pml/slides/norm_79_1.pml
# pml file exists for echino39 as /pml/slides/echino39.pml
# pml file exists for echino14 as /pml/slides/echino14.pml
# pml file exists for norm26 as /pml/slides/norm26.pml
# pml file exists for echino41 as /pml/slides/echino41.pml
# pml file exists for normal2 as /pml/slides/normal2.pml
# pml file exists for Norm21 as /pml/slides/Norm21.pml
# pml file exists for Normalliver19 as /pml/slides/Normalliver19.pml
# pml file exists for echino31 as /pml/slides/echino31.pml
# pml file exists for echino32 as /pml/slides/echino32.pml
# pml file exists for echino13 as /pml/slides/echino13.pml
# pml file exists for echino_71_2 as /pml/slides/echino_71_2.pml
# pml file exists for Norm22 as /pml/slides/Norm22.pml
# pml file exists for echino19 as /pml/slides/echino19.pml
# pml file exists for echino23 as /pml/slides/echino23.pml
# pml file exists for normal5 as /pml/slides/normal5.pml
# pml file exists for normal1 as /pml/slides/normal1.pml
# pml file exists for normal4 as /pml/slides/normal4.pml
# pml file exists for Norm20 as /pml/slides/Norm20.pml
# pml file exists for echino_72_001 as /pml/slides/echino_72_001.pml
# pml file exists for echino_78_2 as /pml/slides/echino_78_2.pml
# pml file exists for normal6 as /pml/slides/normal6.pml
# pml file exists for echino_74_001 as /pml/slides/echino_74_001.pml
# pml file exists for normal8 as /pml/slides/normal8.pml
# pml file exists for echino8 as /pml/slides/echino8.pml
# pml file exists for echino_69_02 as /pml/slides/echino_69_02.pml
# pml file exists for echino3 as /pml/slides/echino3.pml
# pml file exists for norm13 as /pml/slides/norm13.pml
# pml file exists for echino60 as /pml/slides/echino60.pml
# pml file exists for Normalliver18 as /pml/slides/Normalliver18.pml
# pml file exists for echino25 as /pml/slides/echino25.pml
# pml file exists for echino_69_1 as /pml/slides/echino_69_1.pml
# pml file exists for echino_75_002 as /pml/slides/echino_75_002.pml
# pml file exists for echino_71_002 as /pml/slides/echino_71_002.pml
# pml file exists for normal_69_1 as /pml/slides/normal_69_1.pml
# pml file exists for normal7 as /pml/slides/normal7.pml
# pml file exists for echino40 as /pml/slides/echino40.pml
# pml file exists for norm_80_0001 as /pml/slides/norm_80_0001.pml
# pml file exists for echino52 as /pml/slides/echino52.pml
# pml file exists for echino_71_003 as /pml/slides/echino_71_003.pml
# pml file exists for norm_75_001 as /pml/slides/norm_75_001.pml
# pml file exists for norm_72_01 as /pml/slides/norm_72_01.pml
# pml file exists for norm_69_01 as /pml/slides/norm_69_01.pml
# pml file exists for echino_69_4 as /pml/slides/echino_69_4.pml
# pml file exists for echino_76_1 as /pml/slides/echino_76_1.pml
# pml file exists for echino_72_2 as /pml/slides/echino_72_2.pml
# pml file exists for echino30 as /pml/slides/echino30.pml
# pml file exists for echino42 as /pml/slides/echino42.pml
# pml file exists for Normalliver20 as /pml/slides/Normalliver20.pml
# pml file exists for echino21 as /pml/slides/echino21.pml
# pml file exists for normal14 as /pml/slides/normal14.pml
# pml file exists for echino_71_1 as /pml/slides/echino_71_1.pml
# pml file exists for echino62 as /pml/slides/echino62.pml
# pml file exists for Norm23 as /pml/slides/Norm23.pml
# pml file exists for Normalliver15 as /pml/slides/Normalliver15.pml
# pml file exists for echino15 as /pml/slides/echino15.pml
# pml file exists for echino35 as /pml/slides/echino35.pml
# pml file exists for echino_75_001 as /pml/slides/echino_75_001.pml
# pml file exists for echino_71_001 as /pml/slides/echino_71_001.pml
# pml file exists for echino_72_1 as /pml/slides/echino_72_1.pml
# pml file exists for normal9 as /pml/slides/normal9.pml
# pml file exists for echino16 as /pml/slides/echino16.pml
# pml file exists for echino_76_2 as /pml/slides/echino_76_2.pml
# pml file exists for echino_80_1 as /pml/slides/echino_80_1.pml
# pml file exists for norm24 as /pml/slides/norm24.pml
# pml file exists for norm_71_1 as /pml/slides/norm_71_1.pml
# pml file exists for echino29 as /pml/slides/echino29.pml
# pml file exists for echino_69_2 as /pml/slides/echino_69_2.pml
# pml file exists for norm_72_1 as /pml/slides/norm_72_1.pml
# pml file exists for echino27 as /pml/slides/echino27.pml
# pml file exists for echino_73_01 as /pml/slides/echino_73_01.pml
# pml file exists for normal10 as /pml/slides/normal10.pml
# Complete in 0m 0s

# %% [markdown]
# **checking tissue detection results**

# %%
#detectionchecking()

# %% [markdown]
# **Tile extraction**

# %%
#eliminate unwanted directories
#instead of (dev/pathml-tutorial/analysis/tiles$ find -name echinococcus -exec rm -rf {} \;)

# Search for unwanted files and directories
# tiles_to_remove = Path(analysis_dir_path).glob("**/*echinococcus*")
# files = [x for x in p if x.is_file()]
# print(tiles_to_remove)

# Actual delete operation - uncomment to run
# tiles_to_remove.unlink()


# %store -d global_channel_sums
# %store -d global_channel_squared_sums
# %store -d global_tile_count
global_channel_sums = None
global_channel_squared_sums = None
global_tile_count = None

# %%
if (not 'global_channel_sums' in globals()) or (not 'global_channel_squared_sums' in globals()) or (not 'global_tile_count' in globals()):
    # %store -r global_channel_sums
    # %store -r global_channel_squared_sums
    # %store -r global_tile_count   
    
if global_tile_count is None: 
    tilextractor(tile_size)
elif (global_tile_count == 0) or (not 'global_channel_sums' in globals()) or (not 'global_channel_squared_sums' in globals()) or (not 'global_tile_count' in globals()):
    # if no global vars exist, re-run tile extraction
    print("Generating new tiles")
    tilextractor(tile_size)

print(f"global_tile_count: {global_tile_count}")    
print(f"global_channel_squared_sums: {global_channel_squared_sums}")    
print(f"global_channel_sums: {global_channel_sums}")
# Out:
# Tile size is set to 500 pixels
# echino_76_3
# Found 1 class(es) to extract in annotations: ['Tumor']
# Warning: 2 suitable Tumor tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 2 of 2 Tumor tiles and segmentation masks...
# echino61
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 2280 Tumor tiles and segmentation masks...
# echino_72_002
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 1044 Tumor tiles and segmentation masks...
# echino51
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 1752 Tumor tiles and segmentation masks...
# echino_77_1
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 3028 Tumor tiles and segmentation masks...
# norm25
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Extracting 500 of 4965 non_echinococcus tiles and segmentation masks...
# Normalliver16
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Extracting 500 of 5207 non_echinococcus tiles and segmentation masks...
# echino28
# Found 1 class(es) to extract in annotations: ['Tumor']
# Warning: 389 suitable Tumor tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 389 of 389 Tumor tiles and segmentation masks...
# norm12
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Extracting 500 of 1000 non_echinococcus tiles and segmentation masks...
# normal_70
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Extracting 500 of 2448 non_echinococcus tiles and segmentation masks...
# echino_79_1
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 1560 Tumor tiles and segmentation masks...
# echino24
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 1253 Tumor tiles and segmentation masks...
# normal3
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Extracting 500 of 586 non_echinococcus tiles and segmentation masks...
# echino38
# Found 1 class(es) to extract in annotations: ['Tumor']
# Warning: 46 suitable Tumor tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 46 of 46 Tumor tiles and segmentation masks...
# echino26
# Found 1 class(es) to extract in annotations: ['Tumor']
# Warning: 51 suitable Tumor tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 51 of 51 Tumor tiles and segmentation masks...
# echino17
# Found 1 class(es) to extract in annotations: ['Tumor']
# Warning: 239 suitable Tumor tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 239 of 239 Tumor tiles and segmentation masks...
# echino36
# Found 1 class(es) to extract in annotations: ['Tumor']
# Warning: 18 suitable Tumor tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 18 of 18 Tumor tiles and segmentation masks...
# echino_69_03
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 1011 Tumor tiles and segmentation masks...
# echino50
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 1257 Tumor tiles and segmentation masks...
# echino_69_3
# Found 1 class(es) to extract in annotations: ['Tumor']
# Warning: 129 suitable Tumor tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 129 of 129 Tumor tiles and segmentation masks...
# norm_79_1
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Extracting 500 of 3491 non_echinococcus tiles and segmentation masks...
# echino39
# Found 1 class(es) to extract in annotations: ['Tumor']
# Warning: 82 suitable Tumor tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 82 of 82 Tumor tiles and segmentation masks...
# echino14
# Found 1 class(es) to extract in annotations: ['Tumor']
# Warning: 326 suitable Tumor tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 326 of 326 Tumor tiles and segmentation masks...
# /home/ubuntu/dev/pathml/pathml/slide.py:945: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   intersecs = list(intersection)
# /home/ubuntu/dev/pathml/pathml/slide.py:945: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   intersecs = list(intersection)
# norm26
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Extracting 500 of 4578 non_echinococcus tiles and segmentation masks...
# echino41
# Found 1 class(es) to extract in annotations: ['Tumor']
# Warning: 57 suitable Tumor tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 57 of 57 Tumor tiles and segmentation masks...
# normal2
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Extracting 500 of 2691 non_echinococcus tiles and segmentation masks...
# Norm21
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Warning: 325 unannotated tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 325 of 325 non_echinococcus tiles and segmentation masks...
# Normalliver19
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Warning: 48 unannotated tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 48 of 48 non_echinococcus tiles and segmentation masks...
# echino31
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 1096 Tumor tiles and segmentation masks...
# echino32
# Found 1 class(es) to extract in annotations: ['Tumor']
# Warning: 183 suitable Tumor tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 183 of 183 Tumor tiles and segmentation masks...
# echino13
# Found 1 class(es) to extract in annotations: ['Tumor']
# Warning: 36 suitable Tumor tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 36 of 36 Tumor tiles and segmentation masks...
# echino_71_2
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 1172 Tumor tiles and segmentation masks...
# Norm22
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Warning: 27 unannotated tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 27 of 27 non_echinococcus tiles and segmentation masks...
# echino19
# Found 1 class(es) to extract in annotations: ['Tumor']
# Warning: 19 suitable Tumor tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 19 of 19 Tumor tiles and segmentation masks...
# echino23
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 1115 Tumor tiles and segmentation masks...
# normal5
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Extracting 500 of 1218 non_echinococcus tiles and segmentation masks...
# normal1
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Extracting 500 of 1347 non_echinococcus tiles and segmentation masks...
# normal4
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Warning: 99 unannotated tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 99 of 99 non_echinococcus tiles and segmentation masks...
# Norm20
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Extracting 500 of 822 non_echinococcus tiles and segmentation masks...
# echino_72_001
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 1970 Tumor tiles and segmentation masks...
# echino_78_2
# Found 1 class(es) to extract in annotations: ['Tumor']
# Warning: 220 suitable Tumor tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 220 of 220 Tumor tiles and segmentation masks...
# normal6
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Warning: 248 unannotated tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 248 of 248 non_echinococcus tiles and segmentation masks...
# echino_74_001
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 3308 Tumor tiles and segmentation masks...
# normal8
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Extracting 500 of 1772 non_echinococcus tiles and segmentation masks...
# echino8
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 592 Tumor tiles and segmentation masks...
# echino_69_02
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 1920 Tumor tiles and segmentation masks...
# echino3
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 2908 Tumor tiles and segmentation masks...
# norm13
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Extracting 500 of 2463 non_echinococcus tiles and segmentation masks...
# echino60
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 2198 Tumor tiles and segmentation masks...
# Normalliver18
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Extracting 500 of 1783 non_echinococcus tiles and segmentation masks...
# echino25
# Found 1 class(es) to extract in annotations: ['Tumor']
# Warning: 123 suitable Tumor tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 123 of 123 Tumor tiles and segmentation masks...
# echino_69_1
# Found 1 class(es) to extract in annotations: ['Tumor']
# Warning: 157 suitable Tumor tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 157 of 157 Tumor tiles and segmentation masks...
# echino_75_002
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 4595 Tumor tiles and segmentation masks...
# echino_71_002
# Found 1 class(es) to extract in annotations: ['Tumor']
# Warning: 35 suitable Tumor tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 35 of 35 Tumor tiles and segmentation masks...
# normal_69_1
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Extracting 500 of 3078 non_echinococcus tiles and segmentation masks...
# normal7
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Warning: 355 unannotated tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 355 of 355 non_echinococcus tiles and segmentation masks...
# echino40
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 561 Tumor tiles and segmentation masks...
# norm_80_0001
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Extracting 500 of 4530 non_echinococcus tiles and segmentation masks...
# echino52
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 1554 Tumor tiles and segmentation masks...
# echino_71_003
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 642 Tumor tiles and segmentation masks...
# norm_75_001
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Extracting 500 of 4212 non_echinococcus tiles and segmentation masks...
# norm_72_01
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Extracting 500 of 2974 non_echinococcus tiles and segmentation masks...
# norm_69_01
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Extracting 500 of 4456 non_echinococcus tiles and segmentation masks...
# echino_69_4
# Found 1 class(es) to extract in annotations: ['Tumor']
# Warning: 335 suitable Tumor tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 335 of 335 Tumor tiles and segmentation masks...
# echino_76_1
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 5086 Tumor tiles and segmentation masks...
# echino_72_2
# Found 1 class(es) to extract in annotations: ['Tumor']
# Warning: 102 suitable Tumor tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 102 of 102 Tumor tiles and segmentation masks...
# echino30
# Found 1 class(es) to extract in annotations: ['Tumor']
# Warning: 18 suitable Tumor tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 18 of 18 Tumor tiles and segmentation masks...
# echino42
# Found 1 class(es) to extract in annotations: ['Tumor']
# Warning: 252 suitable Tumor tiles found but requested 500 tiles to extract. Extracting all suitable tiles...
# Extracting 252 of 252 Tumor tiles and segmentation masks...
# Normalliver20
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Extracting 500 of 636 non_echinococcus tiles and segmentation masks...
# echino21
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 2019 Tumor tiles and segmentation masks...
# normal14
# No annotations found in tile dictionary; sampling randomly from all suitable tiles
# Extracting 500 of 2925 non_echinococcus tiles and segmentation masks...
# echino_71_1
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 1217 Tumor tiles and segmentation masks...
# echino62
# Found 1 class(es) to extract in annotations: ['Tumor']
# Extracting 500 of 3414 Tumor tiles and segmentation masks...
# Stored 'global_channel_sums' (ndarray)
# Stored 'global_channel_squared_sums' (ndarray)
# Stored 'global_tile_count' (int)
# Complete in 89m 45s
# global_tile_count: 26921
# global_channel_squared_sums: [4.13582480e+09 2.53607573e+09 3.46920710e+09]
# global_channel_sums: [5.18187987e+09 3.91743521e+09 4.72488794e+09]

# %%
# %store -r dataloaders
# %store -r means_and_stds
# %store -r dataset_sizes
# %store -r global_channel_sums
# %store -r global_channel_squared_sums
# %store -r global_tile_count

tileworks(batch_size=48)
# Out:
# Channel means: [0.7699386908059693, 0.5820638477849541, 0.7020375084831544]
# Channel standard deviations: [0.14733369058621432, 0.194984973960881, 0.1503600893990749]
# Total number of echinococcus tiles: 15756
# Total number of non-echninococcus tiles: 11602
# Stored 'dataloaders' (dict)
# Stored 'means_and_stds' (dict)
# Stored 'dataset_sizes' (dict)

# %% [markdown]
# **Visualize Batch**

# %%
vizBatch()

# %% [markdown]
# **Model definition**

# %%
print(f"torch.cuda.device_count(): {torch.cuda.device_count()}")

class_names = ['Tumor','non_echinococcus']

model_ft = models.squeezenet1_0(pretrained=True, progress=False)
model_ft.classifier[1] = nn.Conv2d(512, 2, kernel_size=(1,1), stride=(1,1))

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"using device: {device}")
if torch.cuda.device_count() > 1:
    model_ft = nn.DataParallel(model_ft)
model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)
exp_lr_scheduler = lr_scheduler.StepLR(
    optimizer_ft, step_size=7, gamma=0.1)

# Let`s see the model

print(model_ft.classifier)
# Out:
# torch.cuda.device_count(): 1
# using device: cuda:0
# Sequential(
#   (0): Dropout(p=0.5, inplace=False)
#   (1): Conv2d(512, 2, kernel_size=(1, 1), stride=(1, 1))
#   (2): ReLU(inplace=True)
#   (3): AdaptiveAvgPool2d(output_size=(1, 1))
# )

# %% [markdown]
# **Training**

# %%
start_time = time.time()

epochs = 15

model_ft, learningStats = train_classification_model(model_ft, 
                                                     criterion, 
                                                     optimizer_ft, 
                                                     scheduler=exp_lr_scheduler, 
                                                     num_epochs=epochs)

pickle.dump(learningStats, open(os.path.join(analysis_dir_path, 'classification_results', 
    'classification_learning_stats.p'), 'wb'))
torch.save(model_ft, os.path.join(analysis_dir_path, 'classification_results', 'classification_best_model_ft.pt'))

time_elapsed = time.time() - start_time
print('Complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 413/413 [06:21<00:00,  1.08it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# train 0.17757896002126863 0.9341281066882199 0.9331443063498306 0.934295573385387 0.9341281066882199 0.9341855106223851
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 158/158 [01:47<00:00,  1.47it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# val 0.09811835577605547 0.9621793176408358 0.9642283087197301 0.963286272465146 0.9621793176408358 0.9622559459497925
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 413/413 [06:15<00:00,  1.10it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# train 0.12282541911137491 0.9549909072539907 0.9550115348793045 0.9552165128574415 0.9549909072539907 0.9550469753610883
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 158/158 [01:45<00:00,  1.50it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# val 0.1589367459711654 0.9346733668341709 0.9270123564550885 0.9403093224496798 0.9346733668341709 0.9339793931272651
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 413/413 [06:11<00:00,  1.11it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# train 0.09882197006001307 0.9643362295413215 0.9644769688420036 0.9645058523075748 0.9643362295413215 0.9643758783071366
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 158/158 [01:45<00:00,  1.50it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# val 0.05731765440443747 0.9780481354139117 0.9784298895779762 0.9781426204629587 0.9780481354139117 0.9780619408121158
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 413/413 [06:11<00:00,  1.11it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# train 0.08680994595376713 0.9681753889674681 0.9682353235279904 0.9682983734128107 0.9681753889674681 0.9682051771066308
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 158/158 [01:44<00:00,  1.51it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# val 0.08415468769150208 0.9629727585294896 0.9614101400086507 0.9630627610280617 0.9629727585294896 0.9629290279179705
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 413/413 [06:12<00:00,  1.11it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# train 0.08409120741186057 0.9689836330571833 0.9690840330343967 0.9691084408286532 0.9689836330571833 0.9690131635803402
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 158/158 [01:45<00:00,  1.50it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# val 0.0775726382344512 0.9674689235651944 0.9675335656950997 0.9675341360498223 0.9674689235651944 0.9674840287436367
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 413/413 [06:11<00:00,  1.11it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# train 0.07726513150086557 0.9716104263487573 0.9715606563030139 0.9716918355849447 0.9716104263487573 0.9716314706197424
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 158/158 [01:44<00:00,  1.51it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# val 0.08392271831044441 0.9672044432689765 0.9639758730127241 0.9681788280019527 0.9672044432689765 0.9670915903226647
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 413/413 [06:14<00:00,  1.10it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# train 0.06342583547906518 0.9768640129319054 0.9767739175730514 0.9769121832998652 0.9768640129319054 0.9768769682624171
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 158/158 [01:46<00:00,  1.49it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# val 0.09932887937338603 0.9608569161597461 0.9567016437369129 0.9625142967756177 0.9608569161597461 0.9606718186964106
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 413/413 [06:17<00:00,  1.09it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# train 0.045740474848376664 0.9832289351384118 0.9829916452063956 0.9832410411733031 0.9832289351384118 0.9832329686855122
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 158/158 [01:45<00:00,  1.49it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# val 0.10544594313926685 0.9568897117164771 0.9524721589204281 0.9587147125134645 0.9568897117164771 0.9566711809473816
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 413/413 [06:16<00:00,  1.10it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# train 0.04406268647172808 0.9851990301070923 0.9850267893919407 0.9852107430674871 0.9851990301070923 0.9852027157775919
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 158/158 [01:46<00:00,  1.49it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# val 0.12299716846829714 0.9517323459402275 0.9461468484326563 0.9548017946153359 0.9517323459402275 0.9513961807317535
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 413/413 [06:16<00:00,  1.10it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# train 0.043294030751529225 0.9840876944837341 0.9839876543975936 0.984107519446098 0.9840876944837341 0.9840932748250814
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 158/158 [01:46<00:00,  1.49it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# val 0.14098381228829718 0.9444591377942343 0.93822176296195 0.9481813842666443 0.9444591377942343 0.9440146259874623
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 413/413 [06:14<00:00,  1.10it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# train 0.041570783545150015 0.9850474843402708 0.9847929021238085 0.9850547002599785 0.9850474843402708 0.985050059667318
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 158/158 [01:46<00:00,  1.48it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# val 0.11599278485580305 0.9546416291986247 0.9497575363181866 0.9569201138976382 0.9546416291986247 0.9543786506592724
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 413/413 [06:18<00:00,  1.09it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# train 0.040971217216463914 0.9857546979187715 0.9857283672020765 0.985775405531379 0.9857546979187715 0.9857600539875249
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 158/158 [01:46<00:00,  1.48it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# val 0.14382051437978893 0.9453848188309971 0.9391744367576996 0.9491041484986257 0.9453848188309971 0.9449492867545104
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 413/413 [06:17<00:00,  1.10it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# train 0.04053710807036932 0.9857546979187715 0.9855550240468743 0.9857635546282758 0.9857546979187715 0.9857576383532334
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 158/158 [01:46<00:00,  1.49it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# val 0.10612846500688809 0.9567574715683682 0.9525947634646252 0.9583229517207053 0.9567574715683682 0.9565561011707384
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 413/413 [06:16<00:00,  1.10it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# train 0.040547952291890295 0.9847443928066276 0.9844117991651453 0.9847482974176661 0.9847443928066276 0.9847459733852718
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 158/158 [01:45<00:00,  1.49it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# val 0.12129407075150749 0.9523935466807723 0.947556003637398 0.9545525684116881 0.9523935466807723 0.9521236238143908
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 413/413 [06:17<00:00,  1.09it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# train 0.03785938827374942 0.9862093352192363 0.9859793368029472 0.9862157158739745 0.9862093352192363 0.9862115924019599
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 158/158 [01:45<00:00,  1.49it/s]
# Phase Loss: {:.4f} Acc: {:.4f} Weighted Acc: {:.4f} Weighted Pre: {:.4f} Weighted Rec: {:.4f} Weighted F1: {:.4f}
# val 0.12959537365545484 0.9501454641629199 0.9449017445553274 0.9527176346926871 0.9501454641629199 0.9498304340537248
# Complete in 120m 23s

# %%
plotLearningCurve()

# %% [markdown]
# **Tile level prediction**

# %%
start_time = time.time()

class_names = ['Tumor','non_echinococcus']
means_and_stds = pickle.load(open(os.path.join(analysis_dir_path, 'classification_results', 'trainval_channel_means_and_stds.p'), 'rb'))
modelPath = glob.glob(os.path.join(analysis_dir_path, 'classification_results', 'classification_best_model_ft*'))[0]

dataTransforms = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize(means_and_stds['channel_means'], means_and_stds['channel_stds'])])

trainedModel = models.squeezenet1_0(pretrained=True)
trainedModel.classifier[1] = nn.Conv2d(512, 2, kernel_size=(1,1), stride=(1,1))
trainedModel.load_state_dict(torch.load(modelPath))

for case in val_cases + test_cases:
    pathml_slide = Slide(os.path.join(pathml_slide_dir_path, case+'.pml'))
    pathml_slide.inferClassifier(trainedModel, classNames=class_names, dataTransforms=dataTransforms, tissueLevelThreshold=0.995, foregroundLevelThreshold=88, numWorkers=0, overwriteExistingClassifications=True)
    pathml_slide.save(folder=pathml_slide_dir_path)

time_elapsed = time.time() - start_time
print('Complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
# Out:
# Inferring model on GPU
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:27<00:00,  2.30s/it]
# Inferring model on GPU
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 49/49 [02:00<00:00,  2.46s/it]
# Inferring model on GPU
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 151/151 [05:58<00:00,  2.37s/it]
# Inferring model on GPU
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 75/75 [02:58<00:00,  2.38s/it]
# Inferring model on GPU
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 80/80 [03:11<00:00,  2.39s/it]
# Inferring model on GPU
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 141/141 [05:26<00:00,  2.31s/it]
# Inferring model on GPU
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [03:49<00:00,  2.30s/it]
# Inferring model on GPU
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 149/149 [05:55<00:00,  2.39s/it]
# Inferring model on GPU
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [03:11<00:00,  2.43s/it]
# Inferring model on GPU
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 174/174 [06:54<00:00,  2.38s/it]
# Inferring model on GPU
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 64/64 [02:37<00:00,  2.47s/it]
# Inferring model on GPU
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 77/77 [03:14<00:00,  2.53s/it]
# Inferring model on GPU
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 24/24 [00:58<00:00,  2.42s/it]
# Inferring model on GPU
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 22/22 [00:48<00:00,  2.22s/it]
# Inferring model on GPU
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 78/78 [03:12<00:00,  2.47s/it]
# Inferring model on GPU
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 98/98 [03:49<00:00,  2.34s/it]
# Inferring model on GPU
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 44/44 [01:47<00:00,  2.45s/it]
# Inferring model on GPU
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 149/149 [05:52<00:00,  2.36s/it]
# Inferring model on GPU
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:10<00:00,  2.57s/it]
# Inferring model on GPU
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 194/194 [07:49<00:00,  2.42s/it]
# Inferring model on GPU
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 117/117 [04:46<00:00,  2.44s/it]
# Inferring model on GPU
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 28/28 [01:12<00:00,  2.58s/it]
# Inferring model on GPU
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 116/116 [04:40<00:00,  2.42s/it]
# Inferring model on GPU
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 55/55 [02:18<00:00,  2.51s/it]
# Inferring model on GPU
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 184/184 [07:31<00:00,  2.45s/it]
# Inferring model on GPU
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 136/136 [05:25<00:00,  2.39s/it]
# Inferring model on GPU
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 123/123 [04:53<00:00,  2.39s/it]
# Inferring model on GPU
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 104/104 [04:07<00:00,  2.38s/it]
# Inferring model on GPU
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 94/94 [03:58<00:00,  2.53s/it]
# Inferring model on GPU
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 61/61 [02:29<00:00,  2.46s/it]
# Inferring model on GPU
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 92/92 [03:38<00:00,  2.37s/it]
# Inferring model on GPU
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 107/107 [04:14<00:00,  2.38s/it]
# Inferring model on GPU
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 82/82 [03:21<00:00,  2.46s/it]
# Inferring model on GPU
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 155/155 [06:10<00:00,  2.39s/it]
# Inferring model on GPU
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [01:34<00:00,  2.49s/it]
# Inferring model on GPU
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 107/107 [04:19<00:00,  2.43s/it]
# Inferring model on GPU
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 153/153 [06:09<00:00,  2.42s/it]
# Complete in 141m 15s

# %% [markdown]
# **Visualize inference heatmap**

# %%
vizInferHeatmap_Val()
# Out:
#  Visualizing val cases

# %%
vizInferHeatmap_Test()
# Out:
#  Visualizing test cases

# %% [markdown]
# **Tile level accuracy by probability thresholds**

# %%
probThresholds()
# Out:
# Warning: no annotations found in Slide. All tiles in Slide will be assumed to be negative for Tumor. Run addAnnotations() if there should be annotations in this Slide.
# Warning: no annotations found in Slide. All tiles in Slide will be assumed to be negative for Tumor. Run addAnnotations() if there should be annotations in this Slide.
# Warning: no annotations found in Slide. All tiles in Slide will be assumed to be negative for Tumor. Run addAnnotations() if there should be annotations in this Slide.
# Warning: no annotations found in Slide. All tiles in Slide will be assumed to be negative for Tumor. Run addAnnotations() if there should be annotations in this Slide.
# Warning: no annotations found in Slide. All tiles in Slide will be assumed to be negative for Tumor. Run addAnnotations() if there should be annotations in this Slide.
# Warning: no annotations found in Slide. All tiles in Slide will be assumed to be negative for Tumor. Run addAnnotations() if there should be annotations in this Slide.
# Warning: no annotations found in Slide. All tiles in Slide will be assumed to be negative for Tumor. Run addAnnotations() if there should be annotations in this Slide.
# Best tile-level validation accuracy: 0.8353489435217116
# Threshold that gives the best tile-level validation accuracy: 0.9450000000000001
# Stored 'best_classification_threshold' (float)

# %% [markdown]
# **Test accuracy**

# %%
# %store -r best_classification_threshold

testaccuracy()
# Out:
# Warning: no annotations found in Slide. All tiles in Slide will be assumed to be negative for Tumor. Run addAnnotations() if there should be annotations in this Slide.
# Warning: no annotations found in Slide. All tiles in Slide will be assumed to be negative for Tumor. Run addAnnotations() if there should be annotations in this Slide.
# Warning: no annotations found in Slide. All tiles in Slide will be assumed to be negative for Tumor. Run addAnnotations() if there should be annotations in this Slide.
# Warning: no annotations found in Slide. All tiles in Slide will be assumed to be negative for Tumor. Run addAnnotations() if there should be annotations in this Slide.
# Warning: no annotations found in Slide. All tiles in Slide will be assumed to be negative for Tumor. Run addAnnotations() if there should be annotations in this Slide.
# Warning: no annotations found in Slide. All tiles in Slide will be assumed to be negative for Tumor. Run addAnnotations() if there should be annotations in this Slide.
# Warning: no annotations found in Slide. All tiles in Slide will be assumed to be negative for Tumor. Run addAnnotations() if there should be annotations in this Slide.
# Average test set accuracy at echinococcus probability threshold of 0.9450000000000001: 0.8363815431434073
# Case-by-case test set accuracies:
#          Slide_ID  echinococcus accuracy (>0.945)
# 0          Norm23                        0.991453
# 1   Normalliver15                        1.000000
# 2        echino15                        0.819091
# 3        echino35                        0.932143
# 4   echino_75_001                        0.919401
# 5   echino_71_001                        0.682957
# 6     echino_72_1                        0.799199
# 7         normal9                        0.996812
# 8        echino16                        0.505432
# 9     echino_76_2                        0.807879
# 10    echino_80_1                        0.818247
# 11         norm24                        0.998895
# 12      norm_71_1                        0.999272
# 13       echino29                        0.934107
# 14    echino_69_2                        0.581386
# 15      norm_72_1                        0.995466
# 16       echino27                        0.392450
# 17   echino_73_01                        0.717717
# 18       normal10                        0.999343

# %% [markdown]
# **Slide level tile counts above threshold**

# %%
tilecountslidelevel()
# Out:
#          Slide_ID  echinococcus_ground_truth  echinococcus tile count (>0.945)
# 0          Norm23                          0                                 1
# 1   Normalliver15                          0                                 0
# 2        echino15                          1                              1410
# 3        echino35                          1                               298
# 4   echino_75_001                          1                              3146
# 5   echino_71_001                          1                               686
# 6     echino_72_1                          1                              1158
# 7         normal9                          0                                13
# 8        echino16                          1                              1924
# 9     echino_76_2                          1                              2100
# 10    echino_80_1                          1                              1120
# 11         norm24                          0                                 2
# 12      norm_71_1                          0                                 2
# 13       echino29                          1                               288
# 14    echino_69_2                          1                              1326
# 15      norm_72_1                          0                                21
# 16       echino27                          1                               711
# 17   echino_73_01                          1                              2543
# 18       normal10                          0                                 3
# Stored 'test_tile_counts_df' (DataFrame)

# %% [markdown]
# **AUC**

# %%
# %store -r test_tile_counts_df

finalAUC()

# %%
# !conda list
import IPython; print(IPython.sys_info())
# Out:
# # packages in environment at /home/ubuntu/.conda/envs/pathml-env:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                      1_llvm    conda-forge
# albumentations            1.1.0                    pypi_0    pypi
# alsa-lib                  1.2.3                h516909a_0    conda-forge
# argcomplete               2.0.0              pyhd8ed1ab_0    conda-forge
# argon2-cffi               21.3.0             pyhd8ed1ab_0    conda-forge
# argon2-cffi-bindings      21.2.0           py37h5e8e339_1    conda-forge
# async_generator           1.10                       py_0    conda-forge
# atk-1.0                   2.36.0               h3371d22_4    conda-forge
# attrs                     21.4.0             pyhd8ed1ab_0    conda-forge
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# backports                 1.0                        py_2    conda-forge
# backports.functools_lru_cache 1.6.4              pyhd8ed1ab_0    conda-forge
# bleach                    4.1.0              pyhd8ed1ab_0    conda-forge
# blosc                     1.21.0               h9c3ff4c_0    conda-forge
# boost-cpp                 1.74.0               h312852a_4    conda-forge
# brotli                    1.0.9                h7f98852_6    conda-forge
# brotli-bin                1.0.9                h7f98852_6    conda-forge
# brunsli                   0.1                  h9c3ff4c_0    conda-forge
# bzip2                     1.0.8                h7f98852_4    conda-forge
# c-ares                    1.18.1               h7f98852_0    conda-forge
# c-blosc2                  2.0.4                h5f21a17_1    conda-forge
# ca-certificates           2021.10.8            ha878542_0    conda-forge
# cairo                     1.16.0            h6cf1ce9_1008    conda-forge
# certifi                   2021.10.8        py37h89c1867_1    conda-forge
# cffi                      1.15.0           py37h036bc23_0    conda-forge
# cfitsio                   4.0.0                h9a35b8e_0    conda-forge
# charls                    2.2.0                h9c3ff4c_0    conda-forge
# cloudpickle               2.0.0              pyhd8ed1ab_0    conda-forge
# colorama                  0.4.4              pyh9f0ad1d_0    conda-forge
# cudatoolkit               10.0.130             hf841e97_9    conda-forge
# cycler                    0.11.0             pyhd8ed1ab_0    conda-forge
# cytoolz                   0.11.2           py37h5e8e339_1    conda-forge
# dask-core                 2021.12.0          pyhd8ed1ab_0    conda-forge
# dbus                      1.13.6               h5008d03_3    conda-forge
# debugpy                   1.5.1            py37hcd2ae1e_0    conda-forge
# decorator                 5.1.1              pyhd8ed1ab_0    conda-forge
# defusedxml                0.7.1              pyhd8ed1ab_0    conda-forge
# entrypoints               0.3             pyhd8ed1ab_1003    conda-forge
# eval                      0.0.5                    pypi_0    pypi
# expat                     2.4.2                h9c3ff4c_0    conda-forge
# fftw                      3.3.10          nompi_h77c792f_102    conda-forge
# flit-core                 3.6.0              pyhd8ed1ab_0    conda-forge
# font-ttf-dejavu-sans-mono 2.37                 hab24e00_0    conda-forge
# font-ttf-inconsolata      3.000                h77eed37_0    conda-forge
# font-ttf-source-code-pro  2.038                h77eed37_0    conda-forge
# font-ttf-ubuntu           0.83                 hab24e00_0    conda-forge
# fontconfig                2.13.1            hba837de_1005    conda-forge
# fonts-conda-ecosystem     1                             0    conda-forge
# fonts-conda-forge         1                             0    conda-forge
# fonttools                 4.28.5           py37h5e8e339_0    conda-forge
# freetype                  2.10.4               h0708190_1    conda-forge
# fribidi                   1.0.10               h36c2ea0_0    conda-forge
# fsspec                    2021.11.1          pyhd8ed1ab_0    conda-forge
# gdk-pixbuf                2.42.6               h04a7f16_0    conda-forge
# geos                      3.10.1               h9c3ff4c_1    conda-forge
# gettext                   0.19.8.1          h73d1719_1008    conda-forge
# ghostscript               9.54.0               h9c3ff4c_1    conda-forge
# giflib                    5.2.1                h36c2ea0_2    conda-forge
# glib                      2.70.2               h780b84a_1    conda-forge
# glib-tools                2.70.2               h780b84a_1    conda-forge
# graphite2                 1.3.13            h58526e2_1001    conda-forge
# graphviz                  2.50.0               h85b4f2f_1    conda-forge
# gst-plugins-base          1.18.5               hf529b03_3    conda-forge
# gstreamer                 1.18.5               h9f60fe5_3    conda-forge
# gstreamer-orc             0.4.32               h7f98852_1    conda-forge
# gtk2                      2.24.33              h539f30e_1    conda-forge
# gts                       0.7.6                h64030ff_2    conda-forge
# harfbuzz                  2.9.1                h83ec7ef_1    conda-forge
# hdf5                      1.12.1          nompi_h2750804_103    conda-forge
# icu                       68.2                 h9c3ff4c_0    conda-forge
# imagecodecs               2021.11.20       py37h4167934_1    conda-forge
# imageio                   2.13.5             pyh239f2a4_0    conda-forge
# imagemagick               7.1.0_19        pl5321hb118871_0    conda-forge
# importlib-metadata        4.10.0           py37h89c1867_0    conda-forge
# importlib_metadata        4.10.0               hd8ed1ab_0    conda-forge
# importlib_resources       5.4.0              pyhd8ed1ab_0    conda-forge
# ipykernel                 6.6.1            py37h6531663_0    conda-forge
# ipython                   7.31.0           py37h89c1867_0    conda-forge
# ipython_genutils          0.2.0                      py_1    conda-forge
# jbig                      2.1               h7f98852_2003    conda-forge
# jedi                      0.18.1           py37h89c1867_0    conda-forge
# jinja2                    3.0.3              pyhd8ed1ab_0    conda-forge
# joblib                    1.1.0              pyhd8ed1ab_0    conda-forge
# jpeg                      9d                   h36c2ea0_0    conda-forge
# jsonschema                4.3.3              pyhd8ed1ab_0    conda-forge
# jupyter_client            7.1.0              pyhd8ed1ab_0    conda-forge
# jupyter_core              4.9.1            py37h89c1867_1    conda-forge
# jupyterlab_pygments       0.1.2              pyh9f0ad1d_0    conda-forge
# jxrlib                    1.1                  h7f98852_2    conda-forge
# kiwisolver                1.3.2            py37h2527ec5_1    conda-forge
# krb5                      1.19.2               hcc1bbae_3    conda-forge
# lcms2                     2.12                 hddcbb42_0    conda-forge
# ld_impl_linux-64          2.36.1               hea4e1c9_2    conda-forge
# lerc                      3.0                  h9c3ff4c_0    conda-forge
# libaec                    1.0.6                h9c3ff4c_0    conda-forge
# libblas                   3.9.0           12_linux64_openblas    conda-forge
# libbrotlicommon           1.0.9                h7f98852_6    conda-forge
# libbrotlidec              1.0.9                h7f98852_6    conda-forge
# libbrotlienc              1.0.9                h7f98852_6    conda-forge
# libcblas                  3.9.0           12_linux64_openblas    conda-forge
# libclang                  11.1.0          default_ha53f305_1    conda-forge
# libcurl                   7.81.0               h2574ce0_0    conda-forge
# libdeflate                1.8                  h7f98852_0    conda-forge
# libedit                   3.1.20191231         he28a2e2_2    conda-forge
# libev                     4.33                 h516909a_1    conda-forge
# libevent                  2.1.10               h9b69904_4    conda-forge
# libexif                   0.6.21               h7f98852_0    conda-forge
# libffi                    3.4.2                h7f98852_5    conda-forge
# libgcc-ng                 11.2.0              h1d223b6_11    conda-forge
# libgd                     2.3.3                h6ad9fb6_0    conda-forge
# libgfortran-ng            11.2.0              h69a702a_11    conda-forge
# libgfortran5              11.2.0              h5c6108e_11    conda-forge
# libglib                   2.70.2               h174f98d_1    conda-forge
# libgsf                    1.14.48              h88be47d_0    conda-forge
# libiconv                  1.16                 h516909a_0    conda-forge
# liblapack                 3.9.0           12_linux64_openblas    conda-forge
# libllvm11                 11.1.0               hf817b99_2    conda-forge
# libmatio                  1.5.21               hdf44fe6_1    conda-forge
# libnghttp2                1.43.0               h812cca2_1    conda-forge
# libnsl                    2.0.0                h7f98852_0    conda-forge
# libogg                    1.3.4                h7f98852_1    conda-forge
# libopenblas               0.3.18          pthreads_h8fe5266_0    conda-forge
# libopus                   1.3.1                h7f98852_1    conda-forge
# libpng                    1.6.37               h21135ba_2    conda-forge
# libpq                     13.5                 hd57d9b9_1    conda-forge
# librsvg                   2.52.5               hc3c00ef_1    conda-forge
# libsodium                 1.0.18               h36c2ea0_1    conda-forge
# libssh2                   1.10.0               ha56f1ee_2    conda-forge
# libstdcxx-ng              11.2.0              he4da1e4_11    conda-forge
# libtiff                   4.3.0                h6f004c6_2    conda-forge
# libtool                   2.4.6             h9c3ff4c_1008    conda-forge
# libuuid                   2.32.1            h7f98852_1000    conda-forge
# libvips                   8.12.1               h0a13009_0    conda-forge
# libvorbis                 1.3.7                h9c3ff4c_0    conda-forge
# libwebp                   1.2.1                h3452ae3_0    conda-forge
# libwebp-base              1.2.1                h7f98852_0    conda-forge
# libxcb                    1.13              h7f98852_1004    conda-forge
# libxkbcommon              1.0.3                he3ba5ed_0    conda-forge
# libxml2                   2.9.12               h72842e0_0    conda-forge
# libzlib                   1.2.11            h36c2ea0_1013    conda-forge
# libzopfli                 1.0.3                h9c3ff4c_0    conda-forge
# llvm-openmp               12.0.1               h4bd325d_1    conda-forge
# locket                    0.2.0                      py_2    conda-forge
# lz4-c                     1.9.3                h9c3ff4c_1    conda-forge
# markupsafe                2.0.1            py37h5e8e339_1    conda-forge
# matplotlib                3.5.1            py37h89c1867_0    conda-forge
# matplotlib-base           3.5.1            py37h1058ff1_0    conda-forge
# matplotlib-inline         0.1.3              pyhd8ed1ab_0    conda-forge
# mistune                   0.8.4           py37h5e8e339_1005    conda-forge
# mkl                       2022.0.1           h8d4b97c_803    conda-forge
# munkres                   1.1.4              pyh9f0ad1d_0    conda-forge
# mysql-common              8.0.27               ha770c72_3    conda-forge
# mysql-libs                8.0.27               hfa10184_3    conda-forge
# nbclient                  0.5.9              pyhd8ed1ab_0    conda-forge
# nbconvert                 6.4.0            py37h89c1867_0    conda-forge
# nbformat                  5.1.3              pyhd8ed1ab_0    conda-forge
# ncurses                   6.2                  h58526e2_4    conda-forge
# nest-asyncio              1.5.4              pyhd8ed1ab_0    conda-forge
# networkx                  2.6.3              pyhd8ed1ab_1    conda-forge
# ninja                     1.10.2               h4bd325d_1    conda-forge
# notebook                  6.4.6              pyha770c72_0    conda-forge
# nspr                      4.32                 h9c3ff4c_1    conda-forge
# nss                       3.74                 hb5efdd6_0    conda-forge
# numpy                     1.21.5           py37hf2998dd_0    conda-forge
# olefile                   0.46               pyh9f0ad1d_1    conda-forge
# opencv-python-headless    4.5.5.62                 pypi_0    pypi
# openjpeg                  2.4.0                hb52868f_1    conda-forge
# openslide                 3.4.1                h978ee9a_4    conda-forge
# openssl                   1.1.1l               h7f98852_0    conda-forge
# packaging                 21.3               pyhd8ed1ab_0    conda-forge
# pandas                    1.3.5            py37he8f5f7f_0    conda-forge
# pandoc                    2.16.2               h7f98852_0    conda-forge
# pandocfilters             1.5.0              pyhd8ed1ab_0    conda-forge
# pango                     1.48.10              hb8ff022_1    conda-forge
# parso                     0.8.3              pyhd8ed1ab_0    conda-forge
# partd                     1.2.0              pyhd8ed1ab_0    conda-forge
# pathml                    0.1.dev33+g20c5d7f           dev_0    <develop>
# pcre                      8.45                 h9c3ff4c_0    conda-forge
# perl                      5.32.1          1_h7f98852_perl5    conda-forge
# pexpect                   4.8.0              pyh9f0ad1d_2    conda-forge
# pickleshare               0.7.5                   py_1003    conda-forge
# pillow                    8.4.0            py37h0f21c89_0    conda-forge
# pip                       20.0.2                     py_2    conda-forge
# pixman                    0.40.0               h36c2ea0_0    conda-forge
# pkg-config                0.29.2            h36c2ea0_1008    conda-forge
# pkgconfig                 1.5.5            py37h89c1867_1    conda-forge
# poppler                   21.11.0              ha39eefc_0    conda-forge
# poppler-data              0.4.11               hd8ed1ab_0    conda-forge
# prometheus_client         0.12.0             pyhd8ed1ab_0    conda-forge
# prompt-toolkit            3.0.24             pyha770c72_0    conda-forge
# pthread-stubs             0.4               h36c2ea0_1001    conda-forge
# ptyprocess                0.7.0              pyhd3deb0d_0    conda-forge
# pycparser                 2.21               pyhd8ed1ab_0    conda-forge
# pygments                  2.11.2             pyhd8ed1ab_0    conda-forge
# pyparsing                 3.0.6              pyhd8ed1ab_0    conda-forge
# pyqt                      5.12.3           py37h89c1867_8    conda-forge
# pyqt-impl                 5.12.3           py37hac37412_8    conda-forge
# pyqt5-sip                 4.19.18          py37hcd2ae1e_8    conda-forge
# pyqtchart                 5.12             py37he336c9b_8    conda-forge
# pyqtwebengine             5.12.1           py37he336c9b_8    conda-forge
# pyrsistent                0.18.0           py37h5e8e339_0    conda-forge
# python                    3.7.12          hb7a2778_100_cpython    conda-forge
# python-dateutil           2.8.2              pyhd8ed1ab_0    conda-forge
# python_abi                3.7                     2_cp37m    conda-forge
# pytorch                   1.4.0           py3.7_cuda10.0.130_cudnn7.6.3_0    pytorch
# pytz                      2021.3             pyhd8ed1ab_0    conda-forge
# pyvips                    2.1.16           py37h5e8e339_3    conda-forge
# pywavelets                1.2.0            py37hb1e94ed_1    conda-forge
# pyyaml                    6.0              py37h5e8e339_3    conda-forge
# pyzmq                     22.3.0           py37h336d617_1    conda-forge
# qt                        5.12.9               hda022c4_4    conda-forge
# qudida                    0.0.4                    pypi_0    pypi
# readline                  8.1                  h46c0cb4_0    conda-forge
# scikit-image              0.19.1           py37he8f5f7f_0    conda-forge
# scikit-learn              1.0.2            py37hf9e9bfc_0    conda-forge
# scipy                     1.7.3            py37hf2a6cf1_0    conda-forge
# send2trash                1.8.0              pyhd8ed1ab_0    conda-forge
# setuptools                60.5.0           py37h89c1867_0    conda-forge
# shapely                   1.8.0            py37h9b0f7a3_4    conda-forge
# six                       1.16.0             pyh6c4a22f_0    conda-forge
# snappy                    1.1.8                he1b5a44_3    conda-forge
# sqlite                    3.37.0               h9cd32fc_0    conda-forge
# tbb                       2021.5.0             h4bd325d_0    conda-forge
# terminado                 0.12.1           py37h89c1867_1    conda-forge
# testpath                  0.5.0              pyhd8ed1ab_0    conda-forge
# threadpoolctl             3.0.0              pyh8a188c0_0    conda-forge
# tifffile                  2021.11.2          pyhd8ed1ab_0    conda-forge
# tk                        8.6.11               h27826a3_1    conda-forge
# toolz                     0.11.2             pyhd8ed1ab_0    conda-forge
# torchvision               0.5.0                py37_cu100    pytorch
# tornado                   6.1              py37h5e8e339_2    conda-forge
# tqdm                      4.62.3             pyhd8ed1ab_0    conda-forge
# traitlets                 5.1.1              pyhd8ed1ab_0    conda-forge
# typing_extensions         4.0.1              pyha770c72_0    conda-forge
# unet                      0.7.7                    pypi_0    pypi
# unicodedata2              14.0.0           py37h5e8e339_0    conda-forge
# utils                     1.0.1                    pypi_0    pypi
# wcwidth                   0.2.5              pyh9f0ad1d_2    conda-forge
# webencodings              0.5.1                      py_1    conda-forge
# wheel                     0.37.1             pyhd8ed1ab_0    conda-forge
# xorg-kbproto              1.0.7             h7f98852_1002    conda-forge
# xorg-libice               1.0.10               h7f98852_0    conda-forge
# xorg-libsm                1.2.3             hd9c2040_1000    conda-forge
# xorg-libx11               1.7.2                h7f98852_0    conda-forge
# xorg-libxau               1.0.9                h7f98852_0    conda-forge
# xorg-libxdmcp             1.1.3                h7f98852_0    conda-forge
# xorg-libxext              1.3.4                h7f98852_1    conda-forge
# xorg-libxrender           0.9.10            h7f98852_1003    conda-forge
# xorg-libxt                1.2.1                h7f98852_2    conda-forge
# xorg-renderproto          0.11.1            h7f98852_1002    conda-forge
# xorg-xextproto            7.3.0             h7f98852_1002    conda-forge
# xorg-xproto               7.0.31            h7f98852_1007    conda-forge
# xz                        5.2.5                h516909a_1    conda-forge
# yaml                      0.2.5                h7f98852_2    conda-forge
# zeromq                    4.3.4                h9c3ff4c_1    conda-forge
# zfp                       0.5.5                h9c3ff4c_8    conda-forge
# zipp                      3.7.0              pyhd8ed1ab_0    conda-forge
# zlib                      1.2.11            h36c2ea0_1013    conda-forge
# zstd                      1.5.1                ha95c52a_0    conda-forge
# {'commit_hash': '980a41b',
#  'commit_source': 'installation',
#  'default_encoding': 'UTF-8',
#  'ipython_path': '/home/ubuntu/.conda/envs/pathml-env/lib/python3.7/site-packages/IPython',
#  'ipython_version': '7.31.0',
#  'os_name': 'posix',
#  'platform': 'Linux-5.4.0-99-generic-x86_64-with-debian-bullseye-sid',
#  'sys_executable': '/home/ubuntu/.conda/envs/pathml-env/bin/python',
#  'sys_platform': 'linux',
#  'sys_version': '3.7.12 | packaged by conda-forge | (default, Oct 26 2021, '
#                 '06:08:53) \n'
#                 '[GCC 9.4.0]'}
